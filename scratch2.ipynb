# %%
import nilearn
atlas_name = 'cort-maxprob-thr0-1mm'
atlas = nilearn.datasets.fetch_atlas_harvard_oxford(atlas_name)
# Out:
# Dataset created in /home/stevenm/nilearn_data/fsl
#
# ...
# Downloaded 25716861 of 25716861 bytes (100.0%,    0.0s remaining) ...done. (12 seconds, 0 min)
# Extracting data from /home/stevenm/nilearn_data/fsl/2e149f3ae6f3e6efda0a470782ddf9f9/HarvardOxford.tgz..... done.

# %%
import nibabel as nib
atlas.labels[int(nib.load(atlas.maps).get_fdata()[100,100,100])]
# Out:
# 'Cingulate Gyrus, posterior division'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(nib.load(atlas.maps).get_fdata()[100,:,:].T, origin='lower')
plt.axhline(100)
plt.axvline(100)

# %% [markdown]
# ##
